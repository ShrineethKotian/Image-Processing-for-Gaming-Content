# %%
! git clone https://github.com/xinntao/Real-ESRGAN.git
# Out:
# Cloning into 'Real-ESRGAN'...
# remote: Enumerating objects: 759, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 759 (delta 0), reused 0 (delta 0), pack-reused 757 (from 2)
# Receiving objects: 100% (759/759), 5.39 MiB | 39.40 MiB/s, done.
# Resolving deltas: 100% (406/406), done.

# %%
import os

os.chdir("./Real-ESRGAN")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
# ----> 3 os.chdir("./Real-ESRGAN")
#
# FileNotFoundError: [Errno 2] No such file or directory: './Real-ESRGAN'

# %%
# Install basicsr - https://github.com/xinntao/BasicSR
# We use BasicSR for both training and inference
! pip3 install basicsr
# facexlib and gfpgan are for face enhancement
! pip3 install facexlib
! pip3 install gfpgan
! pip3 install -r requirements.txt
! python3 setup.py develop
# Out:
# ...
# /home/mcstudent/miniconda3/lib/python3.12/site-packages/setuptools/__init__.py:94: _DeprecatedInstaller: setuptools.installer and fetch_build_eggs are deprecated.
# !!
#
#         ********************************************************************************
#         Requirements should be satisfied by a PEP 517 installer.
#         If you are using pip, you can try `pip install --use-pep517`.
#         ********************************************************************************
#
# !!
#   dist.fetch_build_eggs(dist.setup_requires)
# running develop
# /home/mcstudent/miniconda3/lib/python3.12/site-packages/setuptools/command/develop.py:41: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
# ...

# %%
# %cd Real-ESRGAN
# Out:
# [Errno 2] No such file or directory: 'Real-ESRGAN'
# /home/mcstudent/Ganesh/realESRGAN

# %%
! ls
# Out:
# assets			       inputs		    resultsx2
# CODE_OF_CONDUCT.md	       LICENSE		    scripts
# cog_predict.py		       MANIFEST.in	    setup.cfg
# cog.yaml		       options		    setup.py
# docs			       README_CN.md	    tests
# experiments		       README.md	    VERSION
# gfpgan			       realesrgan	    weights
# inference_realesrgan.py        realesrgan.egg-info
# inference_realesrgan_video.py  requirements.txt

# %%
upload_folder = './inputs/input'
result_folder = './resultsx2'

# %%
from os import listdir
from os.path import isfile, join
assets_path = './inputs/input/'
images = [f for f in listdir(assets_path) if isfile(join(assets_path, f))]
print(images)
# Out:
# ['047_00120.jpg', '043_04640.jpg', '004_00120.jpg']

# %%
# !pip3 install torchvision

# %%
for i in images:
    ! python3 inference_realesrgan.py -n RealESRGAN_x4plus -i inputs/input/"$i" --outscale 2.0 --face_enhance
# Out:
# /home/mcstudent/miniconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/mcstudent/miniconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Testing 0 047_00120
# /home/mcstudent/miniconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
